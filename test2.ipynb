# %%
import sys
from pprint import pprint
from urllib.parse import quote_plus
from sqlalchemy import create_engine, inspect, MetaData

DB_CONFIG = {
    "host": "192.168.13.206",
    "database": "test",
    "user": "system",
    "password": "System@123",
    "port": "54321"
}
url = (f"kingbase+ksycopg2://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['database']}")
engine = create_engine(url, pool_pre_ping=True, echo=False)

# %%
import pandas
a=pandas.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
b=a.to_markdown()
b
# Out:
# '|    |   col1 |   col2 |\n|---:|-------:|-------:|\n|  0 |      1 |      3 |\n|  1 |      2 |      4 |'
